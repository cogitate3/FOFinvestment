# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
df0 = pd.read_csv(r"..\rawData\预收款项增速最高排名.txt", sep="\t", header=None)
df0
# Out:
#       0             1      2       3              4        5        6     7   \
# 0    252  002094. 青岛金王   3.87  +0.26%  2020Q1到2022Q1   10.47%   24.66%  0.08
# 1    166  600168. 武汉控股   6.46  +0.31%  2020Q1到2022Q1   54.12%  -25.36%  0.01
# 2    254  600187. 国中水务   2.71  +0.37%  2020Q1到2022Q1    8.67%    2.06%  6.86
# 3    264  600283. 钱江水利  13.75  +0.73%  2020Q2到2022Q2    5.96%  -12.93%  0.01
# 4    275  000826. 启迪环境   3.65   0.00%  2020Q1到2022Q1    4.06%  108.07%  0.00
# ..   ...           ...    ...     ...            ...      ...      ...   ...
# 495  276   300156. 神雾退   0.12       %  2017Q3到2019Q3    3.76%   -1.65%  0.47
# 496  281  600701. 退市工新   0.45       %  2020Q1到2022Q1    2.58%   31.20%  0.53
# 497  293  600652. 退市游久   1.19       %  2020Q1到2022Q1    0.10%   -4.79%  0.04
# 498  398   002359. 北讯退   0.35       %  2019Q1到2021Q1  -22.89%  -43.78%  0.17
# 499  496   002071. 长城退   0.31       %  2019Q1到2021Q1  -43.90%  -39.65%  0.19
#
# ...

# %%
df0.columns = ['序号', '股票',  '价',  '涨',  '最新股息',  '平均股息',
               '扣非PE',  'PB',  'ROE',  '市值(亿)',  '今年来',  '行业']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Albert\OneDrive\github\FOFinvestment\Python\NCfund.ipynb Cell 3 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Albert/OneDrive/github/FOFinvestment/Python/NCfund.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df0.columns = ['序号', '股票',  '价',  '涨',  '最新股息',  '平均股息',
#       <a href='vscode-notebook-cell:/c%3A/Users/Albert/OneDrive/github/FOFinvestment/Python/NCfund.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a>                '扣非PE',  'PB',  'ROE',  '市值(亿)',  '今年来',  '行业']
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5596, in NDFrame.__setattr__(self, name, value)
#    5594 try:
#    5595     object.__getattribute__(self, name)
# -> 5596     return object.__setattr__(self, name, value)
#    5597 except AttributeError:
#    5598     pass
#
# ...
